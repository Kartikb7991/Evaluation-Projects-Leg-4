# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt

# %%
df= pd.read_excel(r'C:\Users\karti\OneDrive\Desktop\Analytics work\ElectionData.xlsx')

# %%
df
# Out:
#        TimeElapsed                time         territoryName  totalMandates  \
# 0                0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
# 1                0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
# 2                0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
# 3                0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
# 4                0 2019-10-06 20:10:02  TerritÃ³rio Nacional              0
# ...            ...                 ...                   ...            ...
# 21638          265 2019-10-07 00:35:01                 Viseu              8
# 21639          265 2019-10-07 00:35:01                 Viseu              8
# 21640          265 2019-10-07 00:35:01                 Viseu              8
# 21641          265 2019-10-07 00:35:01                 Viseu              8
# 21642          265 2019-10-07 00:35:01                 Viseu              8
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21643 entries, 0 to 21642
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TimeElapsed               21643 non-null  int64
#  1   time                      21643 non-null  datetime64[ns]
#  2   territoryName             21643 non-null  object
#  3   totalMandates             21643 non-null  int64
#  4   availableMandates         21643 non-null  int64
#  5   numParishes               21643 non-null  int64
#  6   numParishesApproved       21643 non-null  int64
#  7   blankVotes                21643 non-null  int64
#  8   blankVotesPercentage      21643 non-null  float64
#  9   nullVotes                 21643 non-null  int64
#  10  nullVotesPercentage       21643 non-null  float64
#  11  votersPercentage          21643 non-null  float64
#  12  subscribedVoters          21643 non-null  int64
# ...

# %%
df.shape
# Out:
# (21643, 28)

# %%
df.columns
# Out:
# Index(['TimeElapsed', 'time', 'territoryName', 'totalMandates',
#        'availableMandates', 'numParishes', 'numParishesApproved', 'blankVotes',
#        'blankVotesPercentage', 'nullVotes', 'nullVotesPercentage',
#        'votersPercentage', 'subscribedVoters', 'totalVoters', 'pre.blankVotes',
#        'pre.blankVotesPercentage', 'pre.nullVotes', 'pre.nullVotesPercentage',
#        'pre.votersPercentage', 'pre.subscribedVoters', 'pre.totalVoters',
#        'Party', 'Mandates', 'Percentage', 'validVotesPercentage', 'Votes',
#        'Hondt', 'FinalMandates'],
#       dtype='object')

# %%
sns.heatmap(df.isnull())

# %%
df['territoryName'].unique()
# Out:
# array(['TerritÃ³rio Nacional', 'Aveiro', 'Beja', 'Braga', 'BraganÃ§a',
#        'Castelo Branco', 'Coimbra', 'Ã‰vora', 'Faro', 'Guarda', 'Leiria',
#        'Lisboa', 'Madeira', 'Portalegre', 'Porto', 'SantarÃ©m',
#        'SetÃºbal', 'Viana do Castelo', 'Vila Real', 'Viseu', 'AÃ§ores'],
#       dtype=object)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True,cmap="coolwarm")

# %%
df.drop(['totalMandates','numParishesApproved','blankVotes','nullVotes','subscribedVoters','totalVoters','pre.blankVotes','pre.nullVotes','pre.subscribedVoters','pre.totalVoters','Percentage','Mandates','pre.blankVotesPercentage','pre.votersPercentage'],axis=1,inplace=True)

# %%
df['Party'].unique()
# Out:
# array(['PS', 'PPD/PSD', 'B.E.', 'CDS-PP', 'PCP-PEV', 'PAN', 'CH',
#        'R.I.R.', 'PCTP/MRPP', 'A', 'L', 'IL', 'JPP', 'NC', 'PDR', 'PNR',
#        'PURP', 'PPM', 'MPT', 'PTP', 'MAS'], dtype=object)

# %%
df['Party'].value_counts()
# Out:
# PCTP/MRPP    1127
# IL           1127
# PDR          1127
# B.E.         1127
# PNR          1127
# CH           1127
# L            1127
# PAN          1127
# PS           1127
# A            1127
# PPD/PSD      1127
# PCP-PEV      1127
# CDS-PP       1127
# PPM          1073
# R.I.R.       1026
# PTP          1019
# MPT          1019
# PURP          972
# NC            972
# JPP           486
# MAS           425
# Name: Party, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21643 entries, 0 to 21642
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   TimeElapsed              21643 non-null  int64
#  1   time                     21643 non-null  datetime64[ns]
#  2   territoryName            21643 non-null  object
#  3   availableMandates        21643 non-null  int64
#  4   numParishes              21643 non-null  int64
#  5   blankVotesPercentage     21643 non-null  float64
#  6   nullVotesPercentage      21643 non-null  float64
#  7   votersPercentage         21643 non-null  float64
#  8   pre.nullVotesPercentage  21643 non-null  float64
#  9   Party                    21643 non-null  object
#  10  validVotesPercentage     21643 non-null  float64
#  11  Votes                    21643 non-null  int64
#  12  Hondt                    21643 non-null  int64
#  13  FinalMandates            21643 non-null  int64
# ...

# %%
catcols = ['territoryName','Party']

# %%
sns.pairplot(data=df)

# %%
plt.figure(figsize = (20,20))
df.boxplot(column = ['TimeElapsed','availableMandates','numParishes','validVotesPercentage','Votes','Hondt','blankVotesPercentage','nullVotesPercentage','votersPercentage','pre.nullVotesPercentage'])

# %%
numcols=(['TimeElapsed','availableMandates','numParishes','validVotesPercentage','Votes','Hondt','blankVotesPercentage','nullVotesPercentage','votersPercentage','pre.nullVotesPercentage'])

# %%
q3 = df[numcols].quantile(0.75)
q1 = df[numcols].quantile(0.25)
iqr = q3 - q1
print('IQR')
print(iqr)
# Out:
# IQR
# TimeElapsed                 135.00
# availableMandates             9.00
# numParishes                 167.00
# validVotesPercentage          2.93
# Votes                      4274.00
# Hondt                         0.00
# blankVotesPercentage          0.75
# nullVotesPercentage           0.51
# votersPercentage              4.26
# pre.nullVotesPercentage       0.45
# dtype: float64

# %%
box_func
# Out:
# <function __main__.box_func(numcols)>

# %%
df['Dates'] = pd.to_datetime(df['time']).dt.date
df['Time'] = pd.to_datetime(df['time']).dt.time

# %%
df.head()
# Out:
#    TimeElapsed                time         territoryName  availableMandates  \
# 0            0 2019-10-06 20:10:02  TerritÃ³rio Nacional                226
# 1            0 2019-10-06 20:10:02  TerritÃ³rio Nacional                226
# 2            0 2019-10-06 20:10:02  TerritÃ³rio Nacional                226
# 3            0 2019-10-06 20:10:02  TerritÃ³rio Nacional                226
# 4            0 2019-10-06 20:10:02  TerritÃ³rio Nacional                226
#
#    numParishes  blankVotesPercentage  nullVotesPercentage  votersPercentage  \
# 0         3092                   2.5                  2.3             51.36
# 1         3092                   2.5                  2.3             51.36
# 2         3092                   2.5                  2.3             51.36
# 3         3092                   2.5                  2.3             51.36
# 4         3092                   2.5                  2.3             51.36
#
# ...

# %%
df.drop(['time'],axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Ledates']=pd.DataFrame(le.fit_transform(df.Dates))
df['Letime']=pd.DataFrame(le.fit_transform(df.Time))
df['leterritory']=pd.DataFrame(le.fit_transform(df.territoryName))

# %%
df.drop(['Time','territoryName','Dates'],axis=1,inplace=True)

# %%
df['Party'].value_counts()
# Out:
# PCTP/MRPP    1127
# IL           1127
# PDR          1127
# B.E.         1127
# PNR          1127
# CH           1127
# L            1127
# PAN          1127
# PS           1127
# A            1127
# PPD/PSD      1127
# PCP-PEV      1127
# CDS-PP       1127
# PPM          1073
# R.I.R.       1026
# PTP          1019
# MPT          1019
# PURP          972
# NC            972
# JPP           486
# MAS           425
# Name: Party, dtype: int64

# %%
partyencoded=pd.Series(df['Party'].value_counts())/len(df['Party'])
x=partyencoded.to_dict()
df['Party_encoded']=df['Party'].map(x)
df.head()
# Out:
#    TimeElapsed  availableMandates  numParishes  blankVotesPercentage  \
# 0            0                226         3092                   2.5
# 1            0                226         3092                   2.5
# 2            0                226         3092                   2.5
# 3            0                226         3092                   2.5
# 4            0                226         3092                   2.5
#
#    nullVotesPercentage  votersPercentage  pre.nullVotesPercentage    Party  \
# 0                  2.3             51.36                     1.91       PS
# 1                  2.3             51.36                     1.91  PPD/PSD
# 2                  2.3             51.36                     1.91     B.E.
# 3                  2.3             51.36                     1.91   CDS-PP
# 4                  2.3             51.36                     1.91  PCP-PEV
#
#    validVotesPercentage   Votes  Hondt  FinalMandates  Ledates  Letime  \
# ...

# %%
df.head()
# Out:
#    TimeElapsed  availableMandates  numParishes  blankVotesPercentage  \
# 0            0                226         3092                   2.5
# 1            0                226         3092                   2.5
# 2            0                226         3092                   2.5
# 3            0                226         3092                   2.5
# 4            0                226         3092                   2.5
#
#    nullVotesPercentage  votersPercentage  pre.nullVotesPercentage    Party  \
# 0                  2.3             51.36                     1.91       PS
# 1                  2.3             51.36                     1.91  PPD/PSD
# 2                  2.3             51.36                     1.91     B.E.
# 3                  2.3             51.36                     1.91   CDS-PP
# 4                  2.3             51.36                     1.91  PCP-PEV
#
#    validVotesPercentage   Votes  Hondt  FinalMandates  Ledates  Letime  \
# ...

# %%
df.drop(['Party'],axis=1,inplace=True)
df.head()
# Out:
#    TimeElapsed  availableMandates  numParishes  blankVotesPercentage  \
# 0            0                226         3092                   2.5
# 1            0                226         3092                   2.5
# 2            0                226         3092                   2.5
# 3            0                226         3092                   2.5
# 4            0                226         3092                   2.5
#
#    nullVotesPercentage  votersPercentage  pre.nullVotesPercentage  \
# 0                  2.3             51.36                     1.91
# 1                  2.3             51.36                     1.91
# 2                  2.3             51.36                     1.91
# 3                  2.3             51.36                     1.91
# 4                  2.3             51.36                     1.91
#
#    validVotesPercentage   Votes  Hondt  FinalMandates  Ledates  Letime  \
# 0                 40.22  147993     94            106        0       8
# ...

# %%
df.columns
# Out:
# Index(['TimeElapsed', 'availableMandates', 'numParishes',
#        'blankVotesPercentage', 'nullVotesPercentage', 'votersPercentage',
#        'pre.nullVotesPercentage', 'Party', 'validVotesPercentage', 'Votes',
#        'Hondt', 'FinalMandates', 'Ledates', 'Letime', 'leterritory'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scr=StandardScaler()
sc.fit(df.drop('FinalMandates',axis=1))
scaledfeatures=sc.transform(df.drop('FinalMandates',axis=1))
scaleddata=pd.DataFrame(scaled_features,columns=df.columns[:-1])
scaleddata.head()
# Out:
#    TimeElapsed  availableMandates  numParishes  blankVotesPercentage  \
# 0    -1.714708           6.758472     4.221354             -0.152941
# 1    -1.714708           6.758472     4.221354             -0.152941
# 2    -1.714708           6.758472     4.221354             -0.152941
# 3    -1.714708           6.758472     4.221354             -0.152941
# 4    -1.714708           6.758472     4.221354             -0.152941
#
#    nullVotesPercentage  votersPercentage  pre.nullVotesPercentage  \
# 0             0.902163         -0.128489                 0.340951
# 1             0.902163         -0.128489                 0.340951
# 2             0.902163         -0.128489                 0.340951
# 3             0.902163         -0.128489                 0.340951
# 4             0.902163         -0.128489                 0.340951
#
#    validVotesPercentage     Votes      Hondt  FinalMandates   Ledates  \
# 0              3.217832  1.419284  14.757327      -0.418374 -1.192483
# ...

# %%
df.head()
# Out:
#    TimeElapsed  availableMandates  numParishes  blankVotesPercentage  \
# 0            0                226         3092                   2.5
# 1            0                226         3092                   2.5
# 2            0                226         3092                   2.5
# 3            0                226         3092                   2.5
# 4            0                226         3092                   2.5
#
#    nullVotesPercentage  votersPercentage  pre.nullVotesPercentage  \
# 0                  2.3             51.36                     1.91
# 1                  2.3             51.36                     1.91
# 2                  2.3             51.36                     1.91
# 3                  2.3             51.36                     1.91
# 4                  2.3             51.36                     1.91
#
#    validVotesPercentage   Votes  Hondt  FinalMandates  Ledates  Letime  \
# 0                 40.22  147993     94            106        0       8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21643 entries, 0 to 21642
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   TimeElapsed              21643 non-null  int64
#  1   availableMandates        21643 non-null  int64
#  2   numParishes              21643 non-null  int64
#  3   blankVotesPercentage     21643 non-null  float64
#  4   nullVotesPercentage      21643 non-null  float64
#  5   votersPercentage         21643 non-null  float64
#  6   pre.nullVotesPercentage  21643 non-null  float64
#  7   validVotesPercentage     21643 non-null  float64
#  8   Votes                    21643 non-null  int64
#  9   Hondt                    21643 non-null  int64
#  10  FinalMandates            21643 non-null  int64
#  11  Ledates                  21643 non-null  int32
#  12  Letime                   21643 non-null  int32
#  13  leterritory              21643 non-null  int32
# ...

# %%
X=df.drop(['FinalMandates'],axis=1)    
y=df['FinalMandates']   
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y_Pred = reg.predict(X_test)
Y_Pred
# Out:
# array([ 4.14240194e-02, -6.21160740e-02, -2.61631067e-02, ...,
#         1.09858497e-02,  2.23211676e+01,  2.05808022e+00])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score

# %%
reg.score(X_train, y_train)
# Out:
# 0.9908782602322017

# %%
reg.score(X_test, y_test)
# Out:
# 0.9929240735540666

# %%
mse = mean_squared_error(y_test, Y_Pred)
print('RMSE :', np.sqrt(mse))
print('Variance score: %.2f' % r2_score(y_test, Y_Pred))
# Out:
# RMSE : 0.6305486759963411
# Variance score: 0.99

# %%
from sklearn.ensemble import RandomForestRegressor
RGR = RandomForestRegressor()
RGR.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_pred = RGR.predict(X_test)

# %%
RGR.score(X_train, y_train)
# Out:
# 0.9999745681120636

# %%
RGR.score(X_test, y_test)
# Out:
# 0.9999317286693248

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MAE: 0.006491888700651985
# MSE: 0.0038361209721580513
# RMSE: 0.06193642685978948

# %%
from sklearn.tree import DecisionTreeRegressor  
 
dtr = DecisionTreeRegressor(random_state = 0)

# %%
from sklearn.model_selection import cross_val_score

# %%
tree_scores = cross_val_score(dtr, X_train, y_train, scoring="neg_mean_squared_error", cv=20)
tree_rmse_scores = np.sqrt(-tree_scores)

# %%
dtr.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=0, splitter='best')

# %%
dtr.score(X_train, y_train)
# Out:
# 0.9999977179471994

# %%
dtr.score(X_test, y_test)
# Out:
# 0.9998053927483244

# %% [markdown]
# # THE MODELS APPLIED SHOW HIGH ACCURACIES BUT WE WILL GO WITH RANDOM FOREST REGRESSOR AS IT SHOWS THE HIGHEST ACCURACY
